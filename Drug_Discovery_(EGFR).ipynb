# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhanahoque251/Drug-Discovery-with-Python/blob/main/Drug_Discovery_(EGFR).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install rdkit-pypi pandas
# Out:
# Collecting rdkit-pypi
#   Downloading rdkit_pypi-2022.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 29.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit-pypi) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: rdkit-pypi
# Successfully installed rdkit-pypi-2022.9.5

# %%
# Import necessary libraries
from rdkit import Chem
from rdkit.Chem import Descriptors
import pandas as pd

# %%
! pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.8-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.0.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.31.0)
# Collecting requests-cache~=0.7.0 (from chembl_webresource_client)
#   Downloading requests_cache-0.7.5-py3-none-any.whl (39 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2023.11.17)
# Collecting attrs<22.0,>=21.2 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.1.2)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0.1)
# Collecting url-normalize<2.0,>=1.4 (from requests-cache~=0.7.0->chembl_webresource_client)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)
# Installing collected packages: url-normalize, attrs, requests-cache, chembl_webresource_client
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# jsonschema 4.19.2 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# referencing 0.32.0 requires attrs>=22.2.0, but you have attrs 21.4.0 which is incompatible.
# Successfully installed attrs-21.4.0 chembl_webresource_client-0.10.8 requests-cache-0.7.5 url-normalize-1.4.3

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
# Target search for TRPV1
target = new_client.target
target_query = target.search('EGFR')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references           organism  \
# 0   [{'xref_id': 'Q01279', 'xref_name': None, 'xre...       Mus musculus
# 1                                                  []       Homo sapiens
# 2                                                  []       Homo sapiens
# 3   [{'xref_id': 'P00533', 'xref_name': None, 'xre...       Homo sapiens
# 4                                                  []       Homo sapiens
# 5                                                  []       Homo sapiens
# 6                                                  []       Homo sapiens
# 7                                                  []       Homo sapiens
# 8                                                  []       Homo sapiens
# 9   [{'xref_id': 'P04626', 'xref_name': None, 'xre...       Homo sapiens
# 10  [{'xref_id': 'P06494', 'xref_name': None, 'xre...  Rattus norvegicus
# 11  [{'xref_id': 'Q15303', 'xref_name': None, 'xre...       Homo sapiens
# 12  [{'xref_id': 'P21860', 'xref_name': None, 'xre...       Homo sapiens
# 13                                                 []       Mus musculus
# 14                                                 []       Homo sapiens
# 15                                                 []       Homo sapiens
#
#                                             pref_name  score  \
# 0              Epidermal growth factor receptor erbB1   16.0
# 1                                         EGFR/PPP1CA   16.0
# 2                                            VHL/EGFR   16.0
# 3              Epidermal growth factor receptor erbB1   12.0
# 4   Protein cereblon/Epidermal growth factor receptor   12.0
# 5                    Epidermal growth factor receptor   11.0
# 6   Epidermal growth factor receptor and ErbB2 (HE...   10.0
# 7   MER intracellular domain/EGFR extracellular do...   10.0
# 8                           ErbB-2/ErbB-3 heterodimer   10.0
# 9             Receptor protein-tyrosine kinase erbB-2    9.0
# 10            Receptor protein-tyrosine kinase erbB-2    9.0
# 11            Receptor protein-tyrosine kinase erbB-4    9.0
# 12            Receptor tyrosine-protein kinase erbB-3    9.0
# 13            Receptor tyrosine-protein kinase erbB-2    9.0
# 14                                          FASN/HER2    9.0
# 15  Baculoviral IAP repeat-containing protein 2/Ep...    9.0
#
#     species_group_flag target_chembl_id  \
# 0                False       CHEMBL3608
# 1                False    CHEMBL4523747
# 2                False    CHEMBL4523998
# 3                False        CHEMBL203
# 4                False    CHEMBL4523680
# 5                False    CHEMBL2363049
# 6                False    CHEMBL2111431
# 7                False    CHEMBL3137284
# 8                False    CHEMBL4630723
# 9                False       CHEMBL1824
# 10               False       CHEMBL3848
# 11               False       CHEMBL3009
# 12               False       CHEMBL5838
# 13               False    CHEMBL2311234
# 14               False    CHEMBL4106134
# 15               False    CHEMBL4802031
#
#                                     target_components  \
# 0   [{'accession': 'Q01279', 'component_descriptio...
# 1   [{'accession': 'P00533', 'component_descriptio...
# 2   [{'accession': 'P00533', 'component_descriptio...
# 3   [{'accession': 'P00533', 'component_descriptio...
# 4   [{'accession': 'P00533', 'component_descriptio...
# 5   [{'accession': 'P04626', 'component_descriptio...
# 6   [{'accession': 'P04626', 'component_descriptio...
# 7   [{'accession': 'P00533', 'component_descriptio...
# 8   [{'accession': 'P04626', 'component_descriptio...
# 9   [{'accession': 'P04626', 'component_descriptio...
# 10  [{'accession': 'P06494', 'component_descriptio...
# 11  [{'accession': 'Q15303', 'component_descriptio...
# 12  [{'accession': 'P21860', 'component_descriptio...
# 13  [{'accession': 'P70424', 'component_descriptio...
# 14  [{'accession': 'P04626', 'component_descriptio...
# 15  [{'accession': 'P00533', 'component_descriptio...
#
#                     target_type  tax_id
# 0                SINGLE PROTEIN   10090
# 1   PROTEIN-PROTEIN INTERACTION    9606
# 2   PROTEIN-PROTEIN INTERACTION    9606
# 3                SINGLE PROTEIN    9606
# 4   PROTEIN-PROTEIN INTERACTION    9606
# 5                PROTEIN FAMILY    9606
# 6                PROTEIN FAMILY    9606
# 7              CHIMERIC PROTEIN    9606
# 8               PROTEIN COMPLEX    9606
# 9                SINGLE PROTEIN    9606
# 10               SINGLE PROTEIN   10116
# 11               SINGLE PROTEIN    9606
# 12               SINGLE PROTEIN    9606
# 13               SINGLE PROTEIN   10090
# 14              PROTEIN COMPLEX    9606
# 15  PROTEIN-PROTEIN INTERACTION    9606

# %%
targets.shape
# Out:
# (16, 9)

# %%
selected_target = targets.target_chembl_id[11]
selected_target
# Out:
# 'CHEMBL3009'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None             None
# ..                                                 ...              ...
# 303  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 304  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 305  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 306                                               None             None
# 307                                               None             None
#
#      activity_id                                activity_properties  \
# 0         641521                                                 []
# 1        1681966                                                 []
# 2        1682013                                                 []
# 3        1682014                                                 []
# 4        1682015                                                 []
# ..           ...                                                ...
# 303     24953727  [{'comments': None, 'relation': None, 'result_...
# 304     24953774  [{'comments': None, 'relation': None, 'result_...
# 305     24954237  [{'comments': None, 'relation': None, 'result_...
# 306     24956646  [{'comments': None, 'relation': None, 'result_...
# 307     24957795  [{'comments': None, 'relation': None, 'result_...
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL795907                       Inhibition of erbB4 receptor
# 1      CHEMBL862514  Inhibition of erbB4 fusion protein expressed i...
# 2      CHEMBL862514  Inhibition of erbB4 fusion protein expressed i...
# 3      CHEMBL862514  Inhibition of erbB4 fusion protein expressed i...
# 4      CHEMBL862514  Inhibition of erbB4 fusion protein expressed i...
# ..              ...                                                ...
# 303   CHEMBL5210116  Affinity Phenotypic Cellular interaction (Alam...
# 304   CHEMBL5209937  Affinity Phenotypic Cellular interaction (Cell...
# 305   CHEMBL5210352  Affinity Biochemical interaction (33P-ATP and ...
# 306   CHEMBL5213042  Selectivity interaction (Z’-LYTE assay) EUB000...
# 307   CHEMBL5214832  Selectivity interaction (Enzymatic activity as...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 303          F                    None                   None  BAO_0000190
# 304          F                    None                   None  BAO_0000190
# 305          B                    None                   None  BAO_0000190
# 306          B                    None                   None  BAO_0000190
# 307          B                    None                   None  BAO_0000190
#
#      ... target_organism                         target_pref_name  \
# 0    ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-4
# 1    ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-4
# 2    ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-4
# 3    ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-4
# 4    ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-4
# ..   ...             ...                                      ...
# 303  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-4
# 304  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-4
# 305  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-4
# 306  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-4
# 307  ...    Homo sapiens  Receptor protein-tyrosine kinase erbB-4
#
#     target_tax_id text_value  toid  type units    uo_units upper_value   value
# 0            9606       None  None  IC50    uM  UO_0000065        None    0.02
# 1            9606       None  None  IC50    nM  UO_0000065        None    31.0
# 2            9606       None  None  IC50    nM  UO_0000065        None     0.8
# 3            9606       None  None  IC50    nM  UO_0000065        None     1.2
# 4            9606       None  None  IC50    nM  UO_0000065        None     1.8
# ..            ...        ...   ...   ...   ...         ...         ...     ...
# 303          9606       None  None  IC50    nM  UO_0000065        None  1437.0
# 304          9606       None  None  IC50    nM  UO_0000065        None   360.0
# 305          9606       None  None  IC50    nM  UO_0000065        None    1.58
# 306          9606       None  None  IC50    nM  UO_0000065        None    16.0
# 307          9606       None  None  IC50    nM  UO_0000065        None    14.0
#
# [308 rows x 46 columns]

# %%
print(df.columns)
# Out:
# Index(['action_type', 'activity_comment', 'activity_id', 'activity_properties',
#        'assay_chembl_id', 'assay_description', 'assay_type',
#        'assay_variant_accession', 'assay_variant_mutation', 'bao_endpoint',
#        'bao_format', 'bao_label', 'canonical_smiles', 'data_validity_comment',
#        'data_validity_description', 'document_chembl_id', 'document_journal',
#        'document_year', 'ligand_efficiency', 'molecule_chembl_id',
#        'molecule_pref_name', 'parent_molecule_chembl_id', 'pchembl_value',
#        'potential_duplicate', 'qudt_units', 'record_id', 'relation', 'src_id',
#        'standard_flag', 'standard_relation', 'standard_text_value',
#        'standard_type', 'standard_units', 'standard_upper_value',
#        'standard_value', 'target_chembl_id', 'target_organism',
#        'target_pref_name', 'target_tax_id', 'text_value', 'toid', 'type',
#        'units', 'uo_units', 'upper_value', 'value'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3849 entries, 0 to 3848
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   action_type                87 non-null     object
#  1   activity_comment           1576 non-null   object
#  2   activity_id                3849 non-null   int64
#  3   activity_properties        3849 non-null   object
#  4   assay_chembl_id            3849 non-null   object
#  5   assay_description          3849 non-null   object
#  6   assay_type                 3849 non-null   object
#  7   assay_variant_accession    0 non-null      object
#  8   assay_variant_mutation     0 non-null      object
#  9   bao_endpoint               3849 non-null   object
#  10  bao_format                 3849 non-null   object
#  11  bao_label                  3849 non-null   object
#  12  canonical_smiles           3835 non-null   object
#  13  data_validity_comment      10 non-null     object
#  14  data_validity_description  10 non-null     object
#  15  document_chembl_id         3849 non-null   object
#  16  document_journal           2388 non-null   object
#  17  document_year              3849 non-null   int64
#  18  ligand_efficiency          1943 non-null   object
#  19  molecule_chembl_id         3849 non-null   object
#  20  molecule_pref_name         87 non-null     object
#  21  parent_molecule_chembl_id  3849 non-null   object
#  22  pchembl_value              3082 non-null   object
#  23  potential_duplicate        3849 non-null   int64
#  24  qudt_units                 3769 non-null   object
#  25  record_id                  3849 non-null   int64
#  26  relation                   3734 non-null   object
#  27  src_id                     3849 non-null   int64
#  28  standard_flag              3849 non-null   int64
#  29  standard_relation          3734 non-null   object
#  30  standard_text_value        0 non-null      object
#  31  standard_type              3849 non-null   object
#  32  standard_units             3771 non-null   object
#  33  standard_upper_value       0 non-null      object
#  34  standard_value             3734 non-null   object
#  35  target_chembl_id           3849 non-null   object
#  36  target_organism            3849 non-null   object
#  37  target_pref_name           3849 non-null   object
#  38  target_tax_id              3849 non-null   object
#  39  text_value                 0 non-null      object
#  40  toid                       0 non-null      object
#  41  type                       3849 non-null   object
#  42  units                      3698 non-null   object
#  43  uo_units                   3769 non-null   object
#  44  upper_value                0 non-null      object
#  45  value                      3734 non-null   object
# dtypes: int64(6), object(40)
# memory usage: 1.4+ MB
# None

# %%
df['canonical_smiles']
# Out:
# 0                      O=C(NCc1ccc(Cl)cc1)Nc1cccc2cnccc12
# 1               CCC(C)(C)c1ccc(CCC(=O)Nc2cccc3cnccc23)cc1
# 2                 O=C(NCCc1ccc(Cl)c(Cl)c1)Nc1cccc2cnccc12
# 3            O=C(NCc1ccc(Cl)c(C(F)(F)F)c1)Nc1cccc2cnccc12
# 4       O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc1cccc2cnccc12
#                               ...
# 3844    O=C(Nc1ccccc1[N+](=O)[O-])N1CCC[C@H]1c1ncc(-c2...
# 3845    Cc1ccc(NC(=O)N2CCC[C@H]2c2ncc(-c3ccccc3)s2)c([...
# 3846       O=C(Nc1ccc(F)cc1)N1CCC[C@H]1c1nc(-c2ccccc2)cs1
# 3847    Cc1ccc(C)c(NC(=O)N2CCC[C@H]2c2nc(-c3ccccc3)cs2)c1
# 3848    O=C(Nc1cccc2cnccc12)N1CCC[C@H]1c1nc(-c2ccccc2)cs1
# Name: canonical_smiles, Length: 3849, dtype: object

# %%
len(df.canonical_smiles.unique())
# Out:
# 3222

# %%
from IPython.display import display
from rdkit import Chem
from rdkit.Chem import Draw

# Example SMILES representation of a molecule
smiles = ' O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc1cccc2cnccc12'  # Replace with your molecule's SMILES

# Create an RDKit molecule object from SMILES
mol = Chem.MolFromSmiles(smiles)

if mol is not None:
    # Draw and display the chemical structure in the notebook
    img = Draw.MolToImage(mol)
    display(img)
else:
    print("Invalid SMILES representation. Unable to generate the molecule.")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
df2 = df.drop_duplicates(['canonical_smiles'])
df2
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 3844  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3845  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3846  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3847  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3848  {'action_type': 'ANTAGONIST', 'description': '...             None
#
#       activity_id                                activity_properties  \
# 0          632519                                                 []
# 1          632521                                                 []
# 2          633813                                                 []
# 3          637294                                                 []
# 4          639749                                                 []
# ...           ...                                                ...
# 3844     24903167  [{'comments': None, 'relation': '=', 'result_f...
# 3845     24903168  [{'comments': None, 'relation': '=', 'result_f...
# 3846     24903169  [{'comments': None, 'relation': '=', 'result_f...
# 3847     24903170  [{'comments': None, 'relation': '=', 'result_f...
# 3848     24903171  [{'comments': None, 'relation': '=', 'result_f...
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL820091  Antagonistic activity towards human vanilloid ...
# 1       CHEMBL820091  Antagonistic activity towards human vanilloid ...
# 2       CHEMBL820091  Antagonistic activity towards human vanilloid ...
# 3       CHEMBL820091  Antagonistic activity towards human vanilloid ...
# 4       CHEMBL820091  Antagonistic activity towards human vanilloid ...
# ...              ...                                                ...
# 3844   CHEMBL5161276  Antagonist activity at human TRPV1 expressed i...
# 3845   CHEMBL5161276  Antagonist activity at human TRPV1 expressed i...
# 3846   CHEMBL5161276  Antagonist activity at human TRPV1 expressed i...
# 3847   CHEMBL5161276  Antagonist activity at human TRPV1 expressed i...
# 3848   CHEMBL5161276  Antagonist activity at human TRPV1 expressed i...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             F                    None                   None  BAO_0000190
# 1             F                    None                   None  BAO_0000190
# 2             F                    None                   None  BAO_0000190
# 3             F                    None                   None  BAO_0000190
# 4             F                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 3844          B                    None                   None  BAO_0000190
# 3845          B                    None                   None  BAO_0000190
# 3846          B                    None                   None  BAO_0000190
# 3847          B                    None                   None  BAO_0000190
# 3848          B                    None                   None  BAO_0000190
#
#       ... target_organism    target_pref_name target_tax_id text_value  toid  \
# 0     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 1     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 2     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 4     ...    Homo sapiens  Vanilloid receptor          9606       None  None
# ...   ...             ...                 ...           ...        ...   ...
# 3844  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3845  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3846  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3847  ...    Homo sapiens  Vanilloid receptor          9606       None  None
# 3848  ...    Homo sapiens  Vanilloid receptor          9606       None  None
#
#       type units    uo_units upper_value  value
# 0     IC50    nM  UO_0000065        None    6.0
# 1     IC50    nM  UO_0000065        None   13.0
# 2     IC50    nM  UO_0000065        None   10.0
# 3     IC50    nM  UO_0000065        None    6.0
# 4     IC50    nM  UO_0000065        None   32.0
# ...    ...   ...         ...         ...    ...
# 3844  IC50    nM  UO_0000065        None  12.36
# 3845  IC50    nM  UO_0000065        None  23.92
# 3846  IC50    nM  UO_0000065        None  31.63
# 3847  IC50    nM  UO_0000065        None  44.42
# 3848  IC50    nM  UO_0000065        None  67.61
#
# [3222 rows x 46 columns]

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL102010                 O=C(NCc1ccc(Cl)cc1)Nc1cccc2cnccc12
# 1          CHEMBL104623          CCC(C)(C)c1ccc(CCC(=O)Nc2cccc3cnccc23)cc1
# 2          CHEMBL103590            O=C(NCCc1ccc(Cl)c(Cl)c1)Nc1cccc2cnccc12
# 3          CHEMBL102486       O=C(NCc1ccc(Cl)c(C(F)(F)F)c1)Nc1cccc2cnccc12
# 4          CHEMBL320906  O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc1cccc2cnccc12
# ...                 ...                                                ...
# 3844      CHEMBL5190729  O=C(Nc1ccccc1[N+](=O)[O-])N1CCC[C@H]1c1ncc(-c2...
# 3845      CHEMBL5206746  Cc1ccc(NC(=O)N2CCC[C@H]2c2ncc(-c3ccccc3)s2)c([...
# 3846      CHEMBL5206635     O=C(Nc1ccc(F)cc1)N1CCC[C@H]1c1nc(-c2ccccc2)cs1
# 3847      CHEMBL5204829  Cc1ccc(C)c(NC(=O)N2CCC[C@H]2c2nc(-c3ccccc3)cs2)c1
# 3848      CHEMBL5188200  O=C(Nc1cccc2cnccc12)N1CCC[C@H]1c1nc(-c2ccccc2)cs1
#
#      standard_value
# 0               6.0
# 1              13.0
# 2              10.0
# 3               6.0
# 4              32.0
# ...             ...
# 3844          12.36
# 3845          23.92
# 3846          31.63
# 3847          44.42
# 3848          67.61
#
# [3222 rows x 3 columns]

# %%
bioactivity_threshold = [
    "inactive" if value is None or float(value) >= 10000
    else "active" if float(value) <= 1000
    else "intermediate"
    for value in df3.standard_value
]

# %%
df3.head()
# Out:
#   molecule_chembl_id                                   canonical_smiles  \
# 0       CHEMBL102010                 O=C(NCc1ccc(Cl)cc1)Nc1cccc2cnccc12
# 1       CHEMBL104623          CCC(C)(C)c1ccc(CCC(=O)Nc2cccc3cnccc23)cc1
# 2       CHEMBL103590            O=C(NCCc1ccc(Cl)c(Cl)c1)Nc1cccc2cnccc12
# 3       CHEMBL102486       O=C(NCc1ccc(Cl)c(C(F)(F)F)c1)Nc1cccc2cnccc12
# 4       CHEMBL320906  O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc1cccc2cnccc12
#
#   standard_value
# 0            6.0
# 1           13.0
# 2           10.0
# 3            6.0
# 4           32.0

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df4 = pd.concat([df3, bioactivity_class], axis=1)
df4
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL102010                 O=C(NCc1ccc(Cl)cc1)Nc1cccc2cnccc12
# 1          CHEMBL104623          CCC(C)(C)c1ccc(CCC(=O)Nc2cccc3cnccc23)cc1
# 2          CHEMBL103590            O=C(NCCc1ccc(Cl)c(Cl)c1)Nc1cccc2cnccc12
# 3          CHEMBL102486       O=C(NCc1ccc(Cl)c(C(F)(F)F)c1)Nc1cccc2cnccc12
# 4          CHEMBL320906  O=C(Nc1cc(C(F)(F)F)cc(C(F)(F)F)c1)Nc1cccc2cnccc12
# ...                 ...                                                ...
# 3202                NaN                                                NaN
# 3203                NaN                                                NaN
# 3210                NaN                                                NaN
# 3214                NaN                                                NaN
# 3215                NaN                                                NaN
#
#      standard_value     class
# 0               6.0    active
# 1              13.0    active
# 2              10.0    active
# 3               6.0    active
# 4              32.0    active
# ...             ...       ...
# 3202            NaN  inactive
# 3203            NaN  inactive
# 3210            NaN    active
# 3214            NaN    active
# 3215            NaN    active
#
# [3783 rows x 4 columns]

# %%
# Step 4: Filter molecules based on molecular weight (300-500)
df4['MolecularWeight'] = df4['canonical_smiles'].apply(lambda x: Descriptors.MolWt(Chem.MolFromSmiles(x)))
filtered_df = df[(df4['MolecularWeight'] >= 300) & (df4['MolecularWeight'] <= 500)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-456db98cad95> in <cell line: 2>()
#       1 # Step 4: Filter molecules based on molecular weight (300-500)
# ----> 2 df4['MolecularWeight'] = df4['canonical_smiles'].apply(lambda x: Descriptors.MolWt(Chem.MolFromSmiles(x)))
#       3 filtered_df = df[(df4['MolecularWeight'] >= 300) & (df4['MolecularWeight'] <= 500)]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4769         dtype: float64
#    4770         """
# -> 4771         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4772
#    4773     def _reduce(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1121
#    1122         # self.f is Callable
# -> 1123         return self.apply_standard()
#    1124
#    1125     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1172             else:
#    1173                 values = obj.astype(object)._values
# -> 1174                 mapped = lib.map_infer(
#    1175                     values,
#    1176                     f,
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-21-456db98cad95> in <lambda>(x)
#       1 # Step 4: Filter molecules based on molecular weight (300-500)
# ----> 2 df4['MolecularWeight'] = df4['canonical_smiles'].apply(lambda x: Descriptors.MolWt(Chem.MolFromSmiles(x)))
#       3 filtered_df = df[(df4['MolecularWeight'] >= 300) & (df4['MolecularWeight'] <= 500)]
#
# TypeError: No registered converter was able to produce a C++ rvalue of type std::basic_string<wchar_t, std::char_traits<wchar_t>, std::allocator<wchar_t> > from this Python object of type NoneType

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors
import pandas as pd

# Assuming df4 is your DataFrame with 'canonical_smiles' column

# Filter out rows with empty or invalid SMILES strings
valid_smiles = df4['canonical_smiles'].dropna()  # Drop NaN values if present
valid_molecules = [Chem.MolFromSmiles(smiles) for smiles in valid_smiles]
valid_molecules = [mol for mol in valid_molecules if mol is not None]

# Calculate molecular weights for valid molecules
molecular_weights = [Descriptors.MolWt(mol) for mol in valid_molecules]

# Create a DataFrame with SMILES and molecular weights
valid_data = {'SMILES': valid_smiles[:len(molecular_weights)], 'MolecularWeight': molecular_weights}
valid_df = pd.DataFrame(valid_data)

# Filter based on molecular weight (300-500)
filtered_df = valid_df[(valid_df['MolecularWeight'] >= 300) & (valid_df['MolecularWeight'] <= 500)]


print(filtered_df)

# %%
# Step 5: Visualize the filtered molecules
print("Filtered Molecules:")
print(filtered_df[['SMILES', 'MolecularWeight']])

# %%
# Import additional libraries for advanced drug discovery
from rdkit.Chem import MACCSkeys
from rdkit.Chem import AllChem
from rdkit.Chem import PyMol
from rdkit.Chem import PandasTools

# Step 6: Additional steps for more advanced drug discovery
# Implement further steps such as ligand-based or structure-based virtual screening, molecular docking, etc., depending on your needs.

# Example of ligand-based virtual screening using molecular fingerprints
# Generate MACCS keys for molecules
df['MACCS'] = df['SMILES'].apply(lambda x: MACCSkeys.GenMACCSKeys(Chem.MolFromSmiles(x)))
query_molecule = Chem.MolFromSmiles('Your_SMILES_here')
query_fp = MACCSkeys.GenMACCSKeys(query_molecule)

# Calculate Tanimoto similarity between the query molecule and the dataset
df['Similarity'] = df['MACCS'].apply(lambda x: DataStructs.FingerprintSimilarity(x, query_fp))

# Filter molecules based on similarity threshold (e.g., >0.7)
ligand_screened_df = df[df['Similarity'] > 0.7]

# Visualize the ligand-based screened molecules
print("Ligand-Based Screened Molecules:")
print(ligand_screened_df[['SMILES', 'Similarity']])

# Example of structure-based virtual screening using molecular docking (requires Pybel and PyMOL)
# Note: Pybel and PyMOL need to be installed separately

# Create a PDB file for the query molecule
query_molecule_block = Chem.MolToPDBBlock(query_molecule)
with open('query_molecule.pdb', 'w') as pdb_file:
    pdb_file.write(query_molecule_block)

# Perform molecular docking using Pybel and PyMOL
import pybel

def perform_docking(target_pdb, ligand_pdb):
    mol_target = next(pybel.readfile("pdb", target_pdb))
    mol_ligand = next(pybel.readfile("pdb", ligand_pdb))

    # Perform docking (this is a simplified example)
    # Replace this with a more realistic docking protocol
    docking_result = mol_target.calcdocking(mol_ligand)

    return docking_result

target_pdb_file = 'your_target.pdb'
docking_results = []

for index, row in ligand_screened_df.iterrows():
    ligand_pdb_block = Chem.MolToPDBBlock(Chem.MolFromSmiles(row['SMILES']))
    with open('ligand.pdb', 'w') as pdb_file:
        pdb_file.write(ligand_pdb_block)

    result = perform_docking(target_pdb_file, 'ligand.pdb')
    docking_results.append({'SMILES': row['SMILES'], 'DockingScore': result.score})

# Visualize the structure-based screened molecules
docking_results_df = pd.DataFrame(docking_results)
print("Structure-Based Screened Molecules:")
print(docking_results_df[['canonical_smiles', 'DockingScore']])

# %%
# Import additional libraries for advanced drug discovery
from rdkit.Chem import MACCSkeys
from rdkit.Chem import AllChem
from rdkit.Chem import PyMol
from rdkit.Chem import PandasTools

# Step 6: Additional steps for more advanced drug discovery
# Implement further steps such as ligand-based or structure-based virtual screening, molecular docking, etc., depending on your needs.

# Example of ligand-based virtual screening using molecular fingerprints
# Generate MACCS keys for molecules
df['MACCS'] = df['canonical_smiles'].apply(lambda x: MACCSkeys.GenMACCSKeys(Chem.MolFromSmiles(x)))
query_molecule = Chem.MolFromSmiles('Your_SMILES_here')
query_fp = MACCSkeys.GenMACCSKeys(query_molecule)

# Calculate Tanimoto similarity between the query molecule and the dataset
df['Similarity'] = df['MACCS'].apply(lambda x: DataStructs.FingerprintSimilarity(x, query_fp))

# Filter molecules based on similarity threshold (e.g., >0.7)
ligand_screened_df = df[df['Similarity'] > 0.7]

# Visualize the ligand-based screened molecules
print("Ligand-Based Screened Molecules:")
print(ligand_screened_df[['canonical_smiles', 'Similarity']])

# Example of structure-based virtual screening using molecular docking (requires Pybel and PyMOL)
# Note: Pybel and PyMOL need to be installed separately

# Create a PDB file for the query molecule
query_molecule_block = Chem.MolToPDBBlock(query_molecule)
with open('query_molecule.pdb', 'w') as pdb_file:
    pdb_file.write(query_molecule_block)

# Perform molecular docking using Pybel and PyMOL
import pybel

def perform_docking(target_pdb, ligand_pdb):
    mol_target = next(pybel.readfile("pdb", target_pdb))
    mol_ligand = next(pybel.readfile("pdb", ligand_pdb))

    # Perform docking (this is a simplified example)
    # Replace this with a more realistic docking protocol
    docking_result = mol_target.calcdocking(mol_ligand)

    return docking_result

target_pdb_file = 'your_target.pdb'
docking_results = []

for index, row in ligand_screened_df.iterrows():
    ligand_pdb_block = Chem.MolToPDBBlock(Chem.MolFromSmiles(row['canonical_smiles']))
    with open('ligand.pdb', 'w') as pdb_file:
        pdb_file.write(ligand_pdb_block)

    result = perform_docking(target_pdb_file, 'ligand.pdb')
    docking_results.append({'SMILES': row['canonical_smiles'], 'DockingScore': result.score})

# Visualize the structure-based screened molecules
docking_results_df = pd.DataFrame(docking_results)
print("Structure-Based Screened Molecules:")
print(docking_results_df[['SMILES', 'DockingScore']])
